# %% [markdown]
# # Exercise: Create a Python Package for Cloud-Free Mosaics

# %% [markdown]
# In this exercise, your goal is to:
#
# 1. Create a function that generates a cloud-free mosaic using Sentinel-2 data and Google Earth Engine.
# 2. Turn this function into a reusable Python package.
# 3. Organize your code using proper Python package structure.
# 4. Install your package locally in editable mode.
# 5. Test your package using a script or notebook.

# %% [markdown]
# ## Step 1: Write the Function
# Create a function called `create_cloud_free_mosaic(aoi, start_date, end_date)` that:
# - Filters Sentinel-2 imagery by date and area,
# - Applies a cloud mask using the `QA60` band,
# - Returns a cloud-free median composite.

# %% [markdown]
# ## Step 2: Create the Package Structure
# Use the following folder layout:
#
# ```
# geoapps/
# ├── geoapps/
# │   ├── __init__.py
# │   └── lab03/
# │       ├── __init__.py
# │       └── cloud_mosaic.py  # <- your function goes here
# ├── pyproject.toml
# └── README.md
# ```

# %% [markdown]
# ## Step 3: Create `pyproject.toml`
# Use the following template:
#
# ```toml
# [build-system]
# requires = ["setuptools", "wheel"]
# build-backend = "setuptools.build_meta"
#
# [project]
# name = "geoapps"
# version = "0.1.0"
# requires-python = ">=3.10"
# description = "EO utilities for cloud-free mosaics"
# authors = [
#   { name = "Your Name", email = "your@email.com" }
# ]
#
# [tool.setuptools.packages.find]
# where = ["."]
# exclude = ["tests", "notebooks"]
# ```

# %% [markdown]
# ## Step 4: Install Your Package
# From the root of your project (where `pyproject.toml` is located), run:
#
# ```bash
# pip install -e .
# ```

# %% [markdown]
# ## Step 5: Test the Package
# Create a test script or notebook and try importing your function like this:
#
# ```python
# from geoapps.lab03.cloud_mosaic import create_cloud_free_mosaic
#
# import ee
# ee.Initialize(project='your-ee-project-id')
#
# aoi = ee.Geometry.Rectangle([19.8, 50.0, 20.0, 50.2])
# mosaic = create_cloud_free_mosaic(aoi, '2023-06-01', '2023-07-01')
# print(mosaic.getInfo())
# ```

# %%
from geoapps.lab03 import cloud_mosaic

cloud_mosaic.display_cloud_map()
cloud_mosaic.display_cloud_free_mosaic()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23e9a63fcb2f09407c0f926ec459474c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23e9a63fcb2f09407c0f926ec459474c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23e9a63fcb2f09407c0f926ec459474c = L.map(
#                 &quot;map_23e9a63fcb2f09407c0f926ec459474c&quot;,
#                 {
#                     center: [50.09997336373202, 19.899999999999498],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71cdbc2e1aa8f8c8d64d809b749c1449 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71cdbc2e1aa8f8c8d64d809b749c1449.addTo(map_23e9a63fcb2f09407c0f926ec459474c);
#
#
#             var tile_layer_74dc5fa0600b041f870d266244a8aeca = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-kkosciukk/maps/87d205dcd03f833147721b37a87cb758-83105775d164cc7b099002fcb389cc8d/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74dc5fa0600b041f870d266244a8aeca.addTo(map_23e9a63fcb2f09407c0f926ec459474c);
#
#
#             var tile_layer_518a737c024c1f3a0bd74861bcce709d = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-kkosciukk/maps/526d8c5c535c966fad4224c22e9f2321-bd554281a36b2e4312f744702ec86561/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_d660786f20ee6194103368a239a6f029 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-kkosciukk/maps/ab5b8073b29269d079670b935ae3733b-6ac75b912e9dda0ca50e525337aa9392/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_2a6249a5ffe5b8c695a4c5d543ba26dc = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-kkosciukk/maps/5d845dec2de939b12567ab270b5fb4e3-879e96fbbaecc8a3fee3faa164cfe678/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_4e3459c926c3149b80afd00b6ba22b3a = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-kkosciukk/maps/6bcdf956aef12f1a467e08285805b287-d25c291bed868baeba6ea89e88f93926/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_1fb29acff0a77b675d5f59b55634e0a3 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-kkosciukk/maps/d85ba09a2d47e4189a7640529f368047-c8c5571fdc732447908ea4c31db8e0af/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_d082f6d749ec7b05f83351a219e178e7 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-kkosciukk/maps/9dc9c0a96207544b2b5d64c7a856dfcc-14cc182301ded122600e90613473ab16/tiles/{z}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a32ff2a9c32c78875592d2df2c15f8ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a32ff2a9c32c78875592d2df2c15f8ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a32ff2a9c32c78875592d2df2c15f8ec = L.map(
#                 &quot;map_a32ff2a9c32c78875592d2df2c15f8ec&quot;,
#                 {
#                     center: [50.09997336373202, 19.899999999999498],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90215de694f4f7a9ddc2e7110ad86bcd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90215de694f4f7a9ddc2e7110ad86bcd.addTo(map_a32ff2a9c32c78875592d2df2c15f8ec);
#
#
#             var tile_layer_25a4cd319e721062204f63c41c1906f6 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-kkosciukk/maps/d7438203995bff75020b57484a438bb6-c9a6ceaa3353df80e10fc9270a7e7316/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_25a4cd319e721062204f63c41c1906f6.addTo(map_a32ff2a9c32c78875592d2df2c15f8ec);
#
#
#             var layer_control_902d3c66e3db35cc6b8100cc6dd5b9b6_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_90215de694f4f7a9ddc2e7110ad86bcd,
#                 },
#                 overlays :  {
#                     &quot;S2 cloud-free mosaic&quot; : tile_layer_25a4cd319e721062204f63c41c1906f6,
#                 },
#             };
#             let layer_control_902d3c66e3db35cc6b8100cc6dd5b9b6 = L.control.layers(
#                 layer_control_902d3c66e3db35cc6b8100cc6dd5b9b6_layers.base_layers,
#                 layer_control_902d3c66e3db35cc6b8100cc6dd5b9b6_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_a32ff2a9c32c78875592d2df2c15f8ec);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 6: Bonus – Add a Demo Notebook
# Create a notebook in a separate `notebooks/` folder where you import and visualize the result using `geemap`:
#
# ```python
# import geemap
# Map = geemap.Map(center=[50.1, 19.9], zoom=10)
# Map.addLayer(mosaic, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}, 'Mosaic')
# Map
# ```
